# %%
# %matplotlib inline
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
print (cv2.__version__)
# Out:
# 3.3.1

# %%
# %ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El número de serie del volumen es: 0483-69C8
#
#  Directorio de C:\Users\Neisser\VisionArtificial
#
# 25/10/2017  14:39    <DIR>          .
# 25/10/2017  14:39    <DIR>          ..
# 25/10/2017  14:14    <DIR>          .ipynb_checkpoints
# 25/10/2017  14:36            85,395 binario_invertido.PNG
# 25/10/2017  14:36            71,558 escala_grises.PNG
# 25/10/2017  14:37           100,497 extension.PNG
# 25/10/2017  14:35           109,637 identidad.PNG
# 25/10/2017  14:35            96,982 negativo.PNG
# 25/10/2017  14:50        48,993,071 opencv_python-3.3.1+contrib-cp36-cp36m-win_amd64.whl
# 25/10/2017  14:29             3,458 Operadores_Puntuales.ipynb
# 25/10/2017  14:09           195,426 peru.jpg
# 25/10/2017  14:11            64,461 Practica2.ipynb
# 25/10/2017  14:37            97,988 suma_1.PNG
# 25/10/2017  14:38            99,942 suma_2.PNG
# 25/10/2017  14:35            62,246 umbral.PNG
# ...

# %%
ruta = "peru.jpg"

# %%
imagen = cv2.imread(ruta)
imagen_rgb = cv2.cvtColor(imagen,cv2.COLOR_BGR2RGB)
imagen_gray = cv2.cvtColor(imagen_rgb,cv2.COLOR_RGB2GRAY)
imagen_gray2 = cv2.cvtColor(imagen_gray,cv2.COLOR_GRAY2RGB)

# %%
plt.imshow(imagen_gray2)
plt.show()

# %%
R = imagen_rgb[:,:,0].astype(int)
G = imagen_rgb[:,:,1].astype(int)
B = imagen_rgb[:,:,2].astype(int)

# %%
type(R[0,0])
# Out:
# numpy.int32

# %%
EG = (R+G+B)/3

# %%
type(EG[0][0])
# Out:
# numpy.int32

# %%
EG = EG.astype("uint8")

# %%
type(EG[0][0])
# Out:
# numpy.uint8

# %%
EG.shape
# Out:
# (864L, 1152L)

# %%
EG2 = cv2.cvtColor(EG,cv2.COLOR_GRAY2RGB)

# %%
plt.imshow(EG2)
plt.show()
