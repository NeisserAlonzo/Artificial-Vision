# %%
# %matplotlib inline

# %%
def grayscale():
	pixel = imagen.load()
	x,y = imagen.size
	for i in range(x):
		for j in range(y):
			(r,g,b) = pixel[i,j]
			gris =(r+g+b)/3
			pixel[i,j] = (gris, gris, gris)

# %%
import cv2

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("linux.png")

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.show()

# %%
x = img.shape

# %%
img.size
# Out:
# 120000

# %%
x=img.shape[0]
y=img.shape[1]

print(x,y)
# Out:
# 200 200

# %%
grises = np.zeros(img.shape)

# %%
img = img.astype("uint8")
for i in range(x):
    for j in range(y):
        r,g,b = img[i,j]
        gris = int((r+g+b)/3)
        grises[i,j] = (gris,gris,gris)
# Out:
# C:\Users\Neisser\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: overflow encountered in ubyte_scalars
#   """

# %%
grises = grises.astype("uint8")
plt.imshow(grises)
plt.show()

# %%
for i in range(x):
    for j in range(y):
        if np.all(img[i,j] > 200) or np.all(img[i,j] >100)== True:
            grises[i,j] = 255
        else:
            grises[i,j] = 0

# %%
np.any(img[0,0]>200)
# Out:
# True

# %%
grises = grises.astype("uint8")
plt.imshow(grises)
plt.show
# Out:
# <function matplotlib.pyplot.show>
